# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "http://www.popvortex.com/music/charts/top-100-songs.php/"

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta charset="utf-8"><title>iTunes Top 100 Songs Chart 2024</title><meta name="viewport" content="width=device-width, initial-scale=1"><meta name="description" content="iTunes top 100 songs chart list. The most popular hit music and trending songs of 2024. Chart of today\'s current iTunes top 100 songs is updated daily."><meta property="og:title" content="iTunes Top 100 Songs Chart 2024"/><meta property="og:description" content="Chart of the top 100 songs on iTunes. Chart list of the top 100 song downloads of 2024 is updated daily."/><meta property="og:type" content="article"/><meta property="og:image" content="https://www.popvortex.com/images/logo-facebook.png"/><meta property="og:site_name" content="PopVortex"/><meta property="og:url" content="https://www.popvortex.com/music/charts/top-100-songs.php"/><meta property="fb:admins" content="100000239962942"/><meta property="fb:app_id" content="178831188827052"/><link rel="shortcut icon" href="/fa
# ...

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
#soup.select("body > div.container > div:nth-child(4) > div.col-xs-12.col-md-8 > div.chart-wrapper")
soup.select("div:nth-child(4) > div.col-xs-12.col-md-8 > div.chart-wrapper")
# Out:
# [<div class="chart-wrapper"><div class="feed-item music-chart flex-row new-release" id="chart-position-1"><div class="cover-art col-xs-12 col-sm-4"><p class="chart-position">1</p><img alt="Not Like Us - Kendrick Lamar Cover Art" class="cover-image" data-pin-description="Not Like Us - Kendrick Lamar" data-pin-media="https://is1-ssl.mzstatic.com/image/thumb/Music221/v4/d0/ef/b6/d0efb685-73be-fdee-58c9-be655f4cd4fd/24UMGIM51924.rgb.jpg/1200x1200bb.png" data-pin-url="https://www.popvortex.com/music/charts/top-100-songs.php" height="170" loading="lazy" src="https://is1-ssl.mzstatic.com/image/thumb/Music221/v4/d0/ef/b6/d0efb685-73be-fdee-58c9-be655f4cd4fd/24UMGIM51924.rgb.jpg/170x170bb.png" width="170"/> <audio controls="" controlslist="nodownload" preload="none"><source src="https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview211/v4/5b/24/52/5b2452b4-c210-ab61-c1e0-5c3380ca517e/mzaf_13201730811413684255.plus.aac.p.m4a"/></audio> </div><div class="chart-content col-xs-12 col-sm-8"
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    iTunes Top 100 Songs Chart 2024
#   </title>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="iTunes top 100 songs chart list. The most popular hit music and trending songs of 2024. Chart of today's current iTunes top 100 songs is updated daily." name="description"/>
#   <meta content="iTunes Top 100 Songs Chart 2024" property="og:title">
#    <meta content="Chart of the top 100 songs on iTunes. Chart list of the top 100 song downloads of 2024 is updated daily." property="og:description">
#     <meta content="article" property="og:type">
#      <meta content="https://www.popvortex.com/images/logo-facebook.png" property="og:image"/>
#      <meta content="PopVortex" property="og:site_name"/>
#      <meta content="https://www.popvortex.com/music/charts/top-100-songs.php" property="og:url"/>
#      <meta content="100000239962942" property="fb:admins"/>
# ...

# %%
#  <p class="chart-position">
soup.select("p")
# Out:
# [<p>Chart of <strong>iTunes top 100 songs</strong> downloaded at the Apple iTunes music store today. The iTunes top 100 songs chart list countdown includes the hottest and most popular music hits and singles from all musical genres including today's hot <a href="top-pop-songs.php">pop</a>, <a href="top-rap-songs.php">rap</a>, <a href="top-rock-songs.php">rock</a>, and <a href="top-country-songs.php">country</a> songs.</p>,
#  <p>The chart of the current best selling hot 100 song downloads on iTunes right now is updated daily and is for the top singles in the USA.</p>,
#  <p>The number one song on iTunes right now is <strong><a href="https://music.apple.com/us/album/not-like-us/1744776162?i=1744776167&amp;uo=2&amp;partnerId=11&amp;at=10l4UI" rel="nofollow">Not Like Us by Kendrick Lamar</a></strong>.</p>,
#  <p>Chart of the top 100 hot tracks and singles <span>last updated: <time>May, 8 2024</time></span></p>,
# ...

# %%
soup.select(".artist")
# Out:
# [<em class="artist">Kendrick Lamar</em>,
#  <em class="artist">Shaboozey</em>,
#  <em class="artist">Teddy Swims</em>,
#  <em class="artist">Kendrick Lamar</em>,
#  <em class="artist">Kendrick Lamar</em>,
#  <em class="artist">Falling In Reverse, Tech N9ne &amp; Alex Terrible</em>,
#  <em class="artist">Zhang Zhe Han</em>,
#  <em class="artist">Benson Boone</em>,
#  <em class="artist">Tommy Richman</em>,
#  <em class="artist">Hozier</em>,
#  <em class="artist">Randy Travis</em>,
#  <em class="artist">Shaboozey</em>,
#  <em class="artist">Sabrina Carpenter</em>,
#  <em class="artist">Reba McEntire</em>,
#  <em class="artist">Drake</em>,
#  <em class="artist">Future, Metro Boomin &amp; Kendrick Lamar</em>,
#  <em class="artist">Taylor Swift</em>,
#  <em class="artist">Marshmello &amp; Kane Brown</em>,
#  <em class="artist">Teddy Swims</em>,
#  <em class="artist">Tim McGraw</em>,
#  <em class="artist">Dua Lipa</em>,
#  <em class="artist">Artemas</em>,
# ...

# %%
soup.select(".title")
# Out:
# [<cite class="title">Not Like Us</cite>,
#  <cite class="title">A Bar Song (Tipsy)</cite>,
#  <cite class="title">Lose Control</cite>,
#  <cite class="title">meet the grahams</cite>,
#  <cite class="title">euphoria</cite>,
#  <cite class="title">Ronald</cite>,
#  <cite class="title">Can You Hear Me</cite>,
#  <cite class="title">Beautiful Things</cite>,
#  <cite class="title">MILLION DOLLAR BABY</cite>,
#  <cite class="title">Too Sweet</cite>,
#  <cite class="title">Where That Came From</cite>,
#  <cite class="title">A Bar Song (Tipsy)</cite>,
#  <cite class="title">Espresso</cite>,
#  <cite class="title">I Can't</cite>,
#  <cite class="title">Family Matters</cite>,
#  <cite class="title">Like That</cite>,
#  <cite class="title">Fortnight (feat. Post Malone)</cite>,
#  <cite class="title">Miles On It</cite>,
#  <cite class="title">The Door</cite>,
#  <cite class="title">Live Like You Were Dying</cite>,
#  <cite class="title">Training Season</cite>,
# ...

# %%
soup.select("body > div.container > div:nth-child(4) > div.col-xs-12.col-md-8")
# Out:
# [<div class="col-xs-12 col-md-8" role="article"><h1>iTunes Top 100 Songs Chart</h1><p>Chart of <strong>iTunes top 100 songs</strong> downloaded at the Apple iTunes music store today. The iTunes top 100 songs chart list countdown includes the hottest and most popular music hits and singles from all musical genres including today's hot <a href="top-pop-songs.php">pop</a>, <a href="top-rap-songs.php">rap</a>, <a href="top-rock-songs.php">rock</a>, and <a href="top-country-songs.php">country</a> songs.</p><p>The chart of the current best selling hot 100 song downloads on iTunes right now is updated daily and is for the top singles in the USA.</p><p>The number one song on iTunes right now is <strong><a href="https://music.apple.com/us/album/not-like-us/1744776162?i=1744776167&amp;uo=2&amp;partnerId=11&amp;at=10l4UI" rel="nofollow">Not Like Us by Kendrick Lamar</a></strong>.</p><p>Chart of the top 100 hot tracks and singles <span>last updated: <time>May, 8 2024</time></span></p><p><strong>
# ...

# %%
top100 = soup.select("body > div.container > div:nth-child(4) > div.col-xs-12.col-md-8 > div.chart-wrapper")

# %%
top100
# Out:
# [<div class="chart-wrapper"><div class="feed-item music-chart flex-row new-release" id="chart-position-1"><div class="cover-art col-xs-12 col-sm-4"><p class="chart-position">1</p><img alt="Not Like Us - Kendrick Lamar Cover Art" class="cover-image" data-pin-description="Not Like Us - Kendrick Lamar" data-pin-media="https://is1-ssl.mzstatic.com/image/thumb/Music221/v4/d0/ef/b6/d0efb685-73be-fdee-58c9-be655f4cd4fd/24UMGIM51924.rgb.jpg/1200x1200bb.png" data-pin-url="https://www.popvortex.com/music/charts/top-100-songs.php" height="170" loading="lazy" src="https://is1-ssl.mzstatic.com/image/thumb/Music221/v4/d0/ef/b6/d0efb685-73be-fdee-58c9-be655f4cd4fd/24UMGIM51924.rgb.jpg/170x170bb.png" width="170"/> <audio controls="" controlslist="nodownload" preload="none"><source src="https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview211/v4/5b/24/52/5b2452b4-c210-ab61-c1e0-5c3380ca517e/mzaf_13201730811413684255.plus.aac.p.m4a"/></audio> </div><div class="chart-content col-xs-12 col-sm-8"
# ...

# %%
title=[]
artist=[]
for l in top100:
    for t in l.select(".title"):
        title.append(t.get_text())
    for a in l.select(".artist"):
        artist.append(a.get_text())
print(title)
print(artist)
# Out:
# ['Not Like UsWanna Be', 'A Bar Song (Tipsy)Wanna Be', 'Lose ControlWanna Be', 'meet the grahamsWanna Be', 'euphoriaWanna Be', 'RonaldWanna Be', 'Can You Hear MeWanna Be', 'Beautiful ThingsWanna Be', 'MILLION DOLLAR BABYWanna Be', 'Too SweetWanna Be', 'Where That Came FromWanna Be', 'A Bar Song (Tipsy)Wanna Be', 'EspressoWanna Be', "I Can'tWanna Be", 'Family MattersWanna Be', 'Like ThatWanna Be', 'Fortnight (feat. Post Malone)Wanna Be', 'Miles On ItWanna Be', 'The DoorWanna Be', 'Live Like You Were DyingWanna Be', 'Training SeasonWanna Be', 'i like the way you kiss meWanna Be', 'Save Me (with Lainey Wilson)Wanna Be', 'Halfway To HellWanna Be', 'Cowgirls (feat. ERNEST)Wanna Be', 'Stick SeasonWanna Be', 'IllusionWanna Be', 'Where the Wild Things AreWanna Be', 'Wondering WhyWanna Be', "we can't be friends (wait for your love)Wanna Be", 'AustinWanna Be', 'Lil Boo ThangWanna Be', 'Push UpsWanna Be', 'Take It All BackWanna Be', 'Need a FavorWanna Be', 'Hollywood NightsWanna Be', 'Not TodayW
# ...

# %%
# to combinw the lists into a dataframe
top100_df = pd.DataFrame({"title":title, "artist":artist})
top100_df
# Out:
#                              title                          artist
# 0                      Not Like Us                  Kendrick Lamar
# 1               A Bar Song (Tipsy)                       Shaboozey
# 2                     Lose Control                     Teddy Swims
# 3                 meet the grahams                  Kendrick Lamar
# 4                         euphoria                  Kendrick Lamar
# ..                             ...                             ...
# 94                        Down Bad                    Taylor Swift
# 95  Who’s Afraid of Little Old Me?                    Taylor Swift
# 96                umademeast4r.mp3                           4batz
# 97                       G.R.I.T.S                    Jimmie Allen
# 98                        Wanna Be  GloRilla & Megan Thee Stallion
#
# [99 rows x 2 columns]
